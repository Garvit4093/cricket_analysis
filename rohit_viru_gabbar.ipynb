# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('ODI_data.csv')

# %%
pd.set_option('display.max_columns',None)

# %%
df.head(20)
# Out:
#     Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 0          E Lewis                  65                       65
# 1         N Pooran                  42                       42
# 2       SO Hetmyer                  18                       18
# 3         RL Chase                  18                       18
# 4      SS Cottrell                  17                       17
# 5        JO Holder                 13*                       13
# 6         CH Gayle                  11                       11
# 7          SD Hope                   5                        5
# 8    CR Brathwaite                   0                        0
# 9        KAJ Roach                   0                        0
# 10        O Thomas                   0                        0
# 11         V Kohli                 120                      120
# 12         SS Iyer                  71                       71
# 13         RR Pant                  20                       20
# ...

# %%
df.shape
# Out:
# (67595, 29)

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '40', '6', '4', '87', '54', '46', '30', '12',
#        '69', '39', '14', '10', '9', '8', '7', '82', '52', '41', '15',
#        '98', '43', '19', '111', '48', '36', '25', '67', '60', '84', '59',
#        '55', '47', '85', '49', '45', '34', '29', '22', '74', '28', '77',
#        '50', '32', '23', '35', '122', '100', '95', '103', '113', '53',
#        '96', '27', '64', '58', '33', '31', '73', '56', '86', '62', '106',
#        '24', '57', '104', '26', '66', '51', '118', '105', '101', '21',
#        '79', '44', '102', '88', '80', '72', '97', '68', '89', '38', '83',
#        '63', '148', '166', '90', '76', '37', '70', '124', '94', '140',
#        '153', '107', '117', '121', '92', '78', '75', '114', '115', '130',
#        '128', '151', '110', '138', '135', '109', '61', '179', '170',
#        '112', '116', '91', '143', '93', '123', '145', '81', '150', '162',
# ...

# %%
df=df.dropna(subset=['Innings Runs Scored Num'])

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '40', '6', '4', '87', '54', '46', '30', '12',
#        '69', '39', '14', '10', '9', '8', '7', '82', '52', '41', '15',
#        '98', '43', '19', '111', '48', '36', '25', '67', '60', '84', '59',
#        '55', '47', '85', '49', '45', '34', '29', '22', '74', '28', '77',
#        '50', '32', '23', '35', '122', '100', '95', '103', '113', '53',
#        '96', '27', '64', '58', '33', '31', '73', '56', '86', '62', '106',
#        '24', '57', '104', '26', '66', '51', '118', '105', '101', '21',
#        '79', '44', '102', '88', '80', '72', '97', '68', '89', '38', '83',
#        '63', '148', '166', '90', '76', '37', '70', '124', '94', '140',
#        '153', '107', '117', '121', '92', '78', '75', '114', '115', '130',
#        '128', '151', '110', '138', '135', '109', '61', '179', '170',
#        '112', '116', '91', '143', '93', '123', '145', '81', '150', '162',
# ...

# %%
df=df[df['Innings Runs Scored Num']!='-']

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '40', '6', '4', '87', '54', '46', '30', '12',
#        '69', '39', '14', '10', '9', '8', '7', '82', '52', '41', '15',
#        '98', '43', '19', '111', '48', '36', '25', '67', '60', '84', '59',
#        '55', '47', '85', '49', '45', '34', '29', '22', '74', '28', '77',
#        '50', '32', '23', '35', '122', '100', '95', '103', '113', '53',
#        '96', '27', '64', '58', '33', '31', '73', '56', '86', '62', '106',
#        '24', '57', '104', '26', '66', '51', '118', '105', '101', '21',
#        '79', '44', '102', '88', '80', '72', '97', '68', '89', '38', '83',
#        '63', '148', '166', '90', '76', '37', '70', '124', '94', '140',
#        '153', '107', '117', '121', '92', '78', '75', '114', '115', '130',
#        '128', '151', '110', '138', '135', '109', '61', '179', '170',
#        '112', '116', '91', '143', '93', '123', '145', '81', '150', '162',
# ...

# %%
df['Innings Date']=pd.to_datetime(df['Innings Date'])

# %%
df.head()
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0        E Lewis                  65                      65
# 1       N Pooran                  42                      42
# 2     SO Hetmyer                  18                      18
# 3       RL Chase                  18                      18
# 4    SS Cottrell                  17                      17
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    128                  1.0                   0.0
# 1                     69                  1.0                   0.0
# 2                     31                  1.0                   0.0
# 3                     34                  1.0                   0.0
# 4                     23                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                  80                      8                      1
# ...

# %%
df['year']=df['Innings Date'].dt.year

# %%
df.tail()
# Out:
#        Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 171937       WM Lawry                  27                      27
# 171938    GS Chappell                 22*                      22
# 171939   KR Stackpole                  13                      13
# 171940     IR Redpath                  12                      12
# 171941       RW Marsh                 10*                      10
#
#        Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 171937                     51                  1.0                   0.0
# 171938                     34                  1.0                   1.0
# 171939                     20                  1.0                   0.0
# 171940                     21                  1.0                   0.0
# 171941                     24                  1.0                   1.0
#
#        Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# ...

# %%
filt1=(df.year>=2002) & (df.year<=2013)

# %%
viru_df=df[filt1]

# %%
viru_df.head()
# Out:
#         Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 29634    Misbah-ul-Haq                  51                      51
# 29635        Anwar Ali                 41*                      41
# 29636  Mohammad Hafeez                  41                      41
# 29637       Umar Akmal                  20                      20
# 29638    Sharjeel Khan                  18                      18
#
#       Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 29634                     85                  1.0                   0.0
# 29635                     54                  1.0                   1.0
# 29636                     95                  1.0                   0.0
# 29637                     45                  1.0                   0.0
# 29638                     53                  1.0                   0.0
#
#       Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# ...

# %%
filt2=( df.year>=2013) & (df.year<=2019)

# %%
rohit_df=df[filt2]

# %%
rohit_df.tail()
# Out:
#        Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 35085       Azhar Ali                   2                       2
# 35086   Misbah-ul-Haq                   2                       2
# 35087     Junaid Khan                  0*                       0
# 35088    Kamran Akmal                   0                       0
# 35089  Mohammad Irfan                   0                       0
#
#       Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 35085                      7                  1.0                   0.0
# 35086                      8                  1.0                   0.0
# 35087                      4                  1.0                   1.0
# 35088                      1                  1.0                   0.0
# 35089                      1                  1.0                   0.0
#
#       Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# ...

# %%
df['Innings Runs Scored Num']=df['Innings Runs Scored Num'].astype(int)

# %%
df['Innings Balls Faced']=df['Innings Balls Faced'].astype(int)

# %%
rohit_df.dtypes
# Out:
# Innings Player                           object
# Innings Runs Scored                      object
# Innings Runs Scored Num                   int32
# Innings Minutes Batted                   object
# Innings Batted Flag                     float64
# Innings Not Out Flag                    float64
# Innings Balls Faced                       int32
# Innings Boundary Fours                   object
# Innings Boundary Sixes                   object
# Innings Batting Strike Rate              object
# Innings Number                           object
# Opposition                               object
# Ground                                   object
# Innings Date                     datetime64[ns]
# Country                                  object
# 50's                                    float64
# 100's                                   float64
# Innings Runs Scored Buckets              object
# Innings Overs Bowled                     object
# Innings Bowled Flag                     float64
# ...

# %%
vdf=viru_df[viru_df['Innings Player']=='V Sehwag']

# %%
vdf.tail()
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 94233       V Sehwag                  42                       42
# 94320       V Sehwag                  82                       82
# 94452       V Sehwag                  51                       51
# 94614       V Sehwag                   5                        5
# 94785       V Sehwag                  29                       29
#
#       Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 94233                     49                  1.0                   0.0
# 94320                     70                  1.0                   0.0
# 94452                     81                  1.0                   0.0
# 94614                     11                  1.0                   0.0
# 94785                     42                  1.0                   0.0
#
#        Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# ...

# %%
rdf=rohit_df[rohit_df['Innings Player']=='RG Sharma']

# %%
rdf.tail()
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 32738      RG Sharma                  18                       18
# 32924      RG Sharma                  52                       52
# 33144      RG Sharma                  65                       65
# 34469      RG Sharma                   4                        4
# 34563      RG Sharma                  83                       83
#
#       Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 32738                     54                  1.0                   0.0
# 32924                     78                  1.0                   0.0
# 33144                     96                  1.0                   0.0
# 34469                     15                  1.0                   0.0
# 34563                    135                  1.0                   0.0
#
#        Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# ...

# %%
sum(vdf['Innings Runs Scored Num']),sum (rdf['Innings Runs Scored Num'])
# Out:
# (7536, 6698)

# %%
rpi_viru=sum(vdf['Innings Runs Scored Num'])/len(vdf)

# %%
rpi_viru
# Out:
# 35.051162790697674

# %%
rpi_rohit=sum(rdf['Innings Runs Scored Num'])/len(rdf)
rpi_rohit
# Out:
# 51.92248062015504

# %%
len(vdf),sum(vdf['Innings Not Out Flag'])
# Out:
# (215, 6.0)

# %%
gabbar_df= df[(df['year']>=2013) & (df['year']<=2019)]

# %%
gabbar_df.head()
# Out:
#   Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 0        E Lewis                  65                       65
# 1       N Pooran                  42                       42
# 2     SO Hetmyer                  18                       18
# 3       RL Chase                  18                       18
# 4    SS Cottrell                  17                       17
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    128                  1.0                   0.0
# 1                     69                  1.0                   0.0
# 2                     31                  1.0                   0.0
# 3                     34                  1.0                   0.0
# 4                     23                  1.0                   0.0
#
#    Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                   80                      8                      1
# ...

# %%
gdf=gabbar_df[gabbar_df['Innings Player']=='S Dhawan']

# %%
gdf.tail()
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 32529       S Dhawan                  31                       31
# 32560       S Dhawan                  68                       68
# 32736       S Dhawan                  48                       48
# 32923       S Dhawan                102*                      102
# 33143       S Dhawan                 114                      114
#
#       Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 32529                     40                  1.0                   0.0
# 32560                    140                  1.0                   0.0
# 32736                     70                  1.0                   0.0
# 32923                    183                  1.0                   1.0
# 33143                    159                  1.0                   0.0
#
#        Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# ...

# %%
rpi_gabbar=sum(gdf['Innings Runs Scored Num'])/len(gdf)

# %%
rpi_gabbar
# Out:
# 43.304

# %%
sum(vdf['Innings Not Out Flag']),sum(rdf['Innings Not Out Flag']),sum(gdf['Innings Not Out Flag'])
# Out:
# (6.0, 16.0, 7.0)

# %%
sr_rohit=sum(rdf['Innings Runs Scored Num'])/sum(rdf['Innings Balls Faced'])*100

# %%
sr_viru=sum(vdf['Innings Runs Scored Num'])/sum(vdf['Innings Balls Faced'])*100

# %%
sr_gabbar=sum(gdf['Innings Runs Scored Num'])/sum(gdf['Innings Balls Faced'])*100

# %%
sr_rohit,sr_viru,sr_gabbar
# Out:
# (92.2335444781052, 104.84140233722871, 94.79859894921191)

# %%
sum(rdf["100's"]),sum(vdf["100's"]),sum(gdf["100's"])
# Out:
# (25.0, 14.0, 17.0)

# %%
sum(rdf["50's"]),sum(vdf["50's"]),sum(gdf["50's"])
# Out:
# (30.0, 34.0, 26.0)

# %%
gdf['Innings Runs Scored Num'].median(),rdf['Innings Runs Scored Num'].median(),vdf['Innings Runs Scored Num'].median()
# Out:
# (32.0, 33.0, 25.0)

# %%
rpi_gabbar,rpi_rohit,rpi_viru
# Out:
# (43.304, 51.92248062015504, 35.051162790697674)

# %%
xr=rohit_df[rohit_df['Country']=='India']['Innings Runs Scored Num'].sum()

# %%
xv=viru_df[viru_df['Country']=='India']['Innings Runs Scored Num'].sum()

# %%
xg=gabbar_df[gabbar_df['Country']=='India']['Innings Runs Scored Num'].sum()

# %%
contri_rohit=sum (rdf['Innings Runs Scored Num'])/xr

# %%
contri_viru=sum (vdf['Innings Runs Scored Num'])/xv

# %%
contri_gabbar=sum(gdf['Innings Runs Scored Num'])/xg

# %%
contri_rohit,contri_viru,contri_gabbar
# Out:
# (0.17177001589988203, 0.09581691036236491, 0.1388162281376622)

# %%
filt2=rohit_df['Innings Player']!='RG Sharma'
not_rohit=rohit_df[filt2]

# %%
sr_not_rohit=sum(not_rohit['Innings Runs Scored Num'])/sum(not_rohit['Innings Balls Faced'])*100

# %%
sr_not_rohit,sr_rohit
# Out:
# (85.37397333307126, 92.2335444781052)

# %%
filt3=viru_df['Innings Player']!='V Sehwag'
not_viru=viru_df[filt3]

# %%
sr_not_viru=sum(not_viru['Innings Runs Scored Num'])/sum(not_viru['Innings Balls Faced'])*100

# %%
sr_not_viru,sr_viru
# Out:
# (77.79927728684581, 104.84140233722871)

# %%
filt4=gabbar_df['Innings Player']!='S Dhawan'
not_gabbar=gabbar_df[filt4]

# %%
sr_not_gabbar=sum(not_gabbar['Innings Runs Scored Num'])/sum(not_gabbar['Innings Balls Faced'])*100

# %%
sr_not_gabbar,sr_gabbar
# Out:
# (85.36418216573293, 94.79859894921191)

# %%
rohit_df.groupby(['Innings Player'])[('Innings Runs Scored Num')].sum().sort_values(ascending=False).head(20)
# Out:
# Innings Player
# V Kohli            7520
# RG Sharma          6698
# JE Root            5856
# S Dhawan           5413
# KS Williamson      5310
# LRPL Taylor        4968
# F du Plessis       4944
# Q de Kock          4907
# HM Amla            4897
# EJG Morgan         4743
# AJ Finch           4559
# MJ Guptill         4475
# AB de Villiers     4409
# AD Mathews         4107
# DA Warner          3940
# Mushfiqur Rahim    3849
# JC Buttler         3843
# Mohammad Hafeez    3819
# MS Dhoni           3752
# SPD Smith          3438
# Name: Innings Runs Scored Num, dtype: int32

# %%
viru_df.groupby(['Innings Player'])[('Innings Runs Scored Num')].sum().sort_values(ascending=False).head(20)
# Out:
# Innings Player
# KC Sangakkara       11211
# RT Ponting           9043
# DPMD Jayawardene     8476
# TM Dilshan           7784
# Yuvraj Singh         7739
# CH Gayle             7635
# SR Tendulkar         7623
# MS Dhoni             7600
# MJ Clarke            7581
# V Sehwag             7536
# GC Smith             6989
# JH Kallis            6847
# Mohammad Yousuf      6756
# Younis Khan          6364
# AB de Villiers       6181
# ST Jayasuriya        6129
# AC Gilchrist         5747
# S Chanderpaul        5685
# RR Sarwan            5610
# R Dravid             5578
# Name: Innings Runs Scored Num, dtype: int32

# %%
viru_df.groupby(['Innings Player'])[('Innings Runs Scored Num')].sum().sort_values(ascending=False).head(12).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Innings Player'>

# %%
viru_df['sr']=viru_df['Innings Runs Scored Num']/viru_df['Innings Balls Faced']

# %%
viru_df.head()
# Out:
#         Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 29634    Misbah-ul-Haq                  51                       51
# 29635        Anwar Ali                 41*                       41
# 29636  Mohammad Hafeez                  41                       41
# 29637       Umar Akmal                  20                       20
# 29638    Sharjeel Khan                  18                       18
#
#       Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 29634                     85                  1.0                   0.0
# 29635                     54                  1.0                   1.0
# 29636                     95                  1.0                   0.0
# 29637                     45                  1.0                   0.0
# 29638                     53                  1.0                   0.0
#
#        Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# ...

# %%
rohit_df['sr']=rohit_df['Innings Runs Scored Num']/rohit_df['Innings Balls Faced']

# %%
rohit_df.head()
# Out:
#   Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 0        E Lewis                  65                       65
# 1       N Pooran                  42                       42
# 2     SO Hetmyer                  18                       18
# 3       RL Chase                  18                       18
# 4    SS Cottrell                  17                       17
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    128                  1.0                   0.0
# 1                     69                  1.0                   0.0
# 2                     31                  1.0                   0.0
# 3                     34                  1.0                   0.0
# 4                     23                  1.0                   0.0
#
#    Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                   80                      8                      1
# ...

# %%
vdf.head()
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 35069       V Sehwag                  31                       31
# 35116       V Sehwag                   4                        4
# 35994       V Sehwag                  34                       34
# 36041       V Sehwag                   3                        3
# 36082       V Sehwag                  15                       15
#
#       Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 35069                     70                  1.0                   0.0
# 35116                     20                  1.0                   0.0
# 35994                     46                  1.0                   0.0
# 36041                      6                  1.0                   0.0
# 36082                     21                  1.0                   0.0
#
#        Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# ...

# %%
x=viru_df.groupby(['Innings Player'])

# %%
y=(x['Innings Runs Scored Num'].sum()/x['Innings Balls Faced'].sum()).sort_values(ascending=False)

# %%
xdf=pd.DataFrame(y)

# %%
xdf.head()
# Out:
#                        0
# Innings Player
# AF Milne        4.000000
# J Louw          3.285714
# Hasti Gul       2.090909
# Fawad Ahmed     2.000000
# G Chapple       2.000000

# %%
xdf.reset_index(inplace=True)

# %%
xdf.head()
# Out:
#   Innings Player         0
# 0       AF Milne  4.000000
# 1         J Louw  3.285714
# 2      Hasti Gul  2.090909
# 3    Fawad Ahmed  2.000000
# 4      G Chapple  2.000000

# %%
xdf['Innings Player']=='V Sehwag'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 820    False
# 821    False
# 822    False
# 823    False
# 824    False
# Name: Innings Player, Length: 825, dtype: bool

# %%
count=0
for i in range(len(xdf)):
    if (xdf['Innings Player'][i]=='V Sehwag'):
        break
    else:
        count+=1
print(count)
# Out:
# 46

# %%
xdf.head(47)
# Out:
#       Innings Player         0
# 0           AF Milne  4.000000
# 1             J Louw  3.285714
# 2          Hasti Gul  2.090909
# 3        Fawad Ahmed  2.000000
# 4          G Chapple  2.000000
# 5         MDJ Walker  1.666667
# 6       Tanvir Ahmed  1.500000
# 7            RM West  1.487805
# 8       Dolar Mahmud  1.386364
# 9      MV Nagamootoo  1.368421
# 10        PJK Mooney  1.333333
# 11     PS Eaglestone  1.333333
# 12         M Zondeki  1.333333
# 13    Kamran Hussain  1.333333
# 14        GJ Maxwell  1.317010
# 15          MD Bates  1.300000
# 16     Shahid Afridi  1.298418
# 17   JJ van der Wath  1.271429
# 18    Bilawal Bhatti  1.265306
# 19        JC Buttler  1.262712
# 20       Naumanullah  1.250000
# 21         KJ Abbott  1.250000
# 22      PD McGlashan  1.235294
# 23          L Ronchi  1.207865
# 24        AD Russell  1.193490
# 25       BJ Diamanti  1.181818
# 26       AM Blignaut  1.179669
# 27       JP Faulkner  1.169054
# 28         PM Siddle  1.166667
# ...

# %%
x1=rohit_df.groupby(['Innings Player'])

# %%
y1=(x1['Innings Runs Scored Num'].sum()/x1['Innings Balls Faced'].sum()).sort_values(ascending=False)
y1
# Out:
# Innings Player
# Fawad Ahmed         2.000000
# SC Kuggeleijn       1.833333
# Mohammad Hasnain    1.555556
# DJ Worrall          1.500000
# AD Russell          1.473154
#                       ...
# Mohammad Talha      0.000000
# Raza Hasan          0.000000
# T Shamsi            0.000000
# Robiul Islam        0.000000
# AW Mathieson             NaN
# Length: 588, dtype: float64

# %%
x1df=pd.DataFrame(y1)

# %%
x1df.reset_index(inplace=True)

# %%
x1df.head()
# Out:
#      Innings Player         0
# 0       Fawad Ahmed  2.000000
# 1     SC Kuggeleijn  1.833333
# 2  Mohammad Hasnain  1.555556
# 3        DJ Worrall  1.500000
# 4        AD Russell  1.473154

# %%
count=0
for i in range(len(x1df)):
    if (x1df['Innings Player'][i]=='RG Sharma'):
        break
    else:
        count+=1
print(count)
# Out:
# 132

# %%
count=0
for i in range(len(x1df)):
    if (x1df['Innings Player'][i]=='S Dhawan'):
        break
    else:
        count+=1
print(count)
# Out:
# 116

# %%
rdf.groupby(['year'])['Innings Runs Scored Num'].sum(),rdf['year'].value_counts()[rdf['year'].unique()]
# Out:
# (year
#  2013    1196
#  2014     578
#  2015     815
#  2016     564
#  2017    1293
#  2018    1030
#  2019    1222
#  Name: Innings Runs Scored Num, dtype: int32,
#  2019    23
#  2018    19
#  2017    21
#  2016    10
#  2015    17
#  2014    12
#  2013    27
#  Name: year, dtype: int64)

# %%
#year_group=rdf.groupby(['year'])

# %%
#year_group.get_group(2015)

# %%
#year_group.value_counts()

# %%
vdf.groupby(['year'])['Innings Runs Scored Num'].sum(),vdf['year'].value_counts()[vdf['year'].unique()]
# Out:
# (year
#  2002    1130
#  2003     871
#  2004     671
#  2005     844
#  2006     608
#  2007     370
#  2008     893
#  2009     810
#  2010     446
#  2011     645
#  2012     217
#  2013      31
#  Name: Innings Runs Scored Num, dtype: int32,
#  2013     1
#  2012    10
#  2011    12
#  2010    12
#  2009    19
#  2008    18
#  2007    11
#  2006    23
#  2005    26
#  2004    26
#  2003    27
#  2002    30
#  Name: year, dtype: int64)

# %%
not_rohit_df=rohit_df[rohit_df['Innings Player']!='RG Sharma']

# %%
not_viru_df=viru_df[viru_df['Innings Player']!='V Sehwag']

# %%
not_gabbar_df=gabbar_df[gabbar_df['Innings Player']!='S Dhawan']

# %%
rpi_not_rohit=sum(not_rohit_df['Innings Runs Scored Num'])/len(not_rohit_df)

# %%
rpi_not_rohit,rpi_rohit
# Out:
# (25.23712687922144, 51.92248062015504)

# %%
rpi_not_viru=sum(not_viru_df['Innings Runs Scored Num'])/len(not_viru_df)

# %%
rpi_not_viru,rpi_viru
# Out:
# (23.54885974240813, 35.051162790697674)

# %%
rpi_not_gabbar=sum(not_gabbar_df['Innings Runs Scored Num'])/len(not_gabbar_df)

# %%
rpi_not_gabbar,rpi_gabbar
# Out:
# (25.323095912292167, 43.304)

# %%
rpi_factor_rohit=rpi_rohit/rpi_not_rohit
rpi_factor_viru=rpi_viru/rpi_not_viru
rpi_factor_gabbar=rpi_gabbar/rpi_not_gabbar

# %%
rpi_factor_rohit,rpi_factor_viru,rpi_factor_gabbar
# Out:
# (2.0573847755587638, 1.4884441613780366, 1.7100594710056627)

# %%
sr_factor_rohit=sr_rohit/sr_not_rohit
sr_factor_viru=sr_viru/sr_not_viru
sr_factor_gabbar=sr_gabbar/sr_not_gabbar

# %%
sr_factor_rohit,sr_factor_viru,sr_factor_gabbar
# Out:
# (1.0803473339383252, 1.3475883837670963, 1.1105196177614898)

# %%
mpc_rohit=len(rdf)/sum(rdf["100's"])

# %%
mpc_rohit,mpc_viru,mpc_gabbar
# Out:
# (5.16, 15.357142857142858, 7.352941176470588)

# %%
mpc_viru=len(vdf)/sum(vdf["100's"])
mpc_gabbar=len(gdf)/sum(gdf["100's"])

# %%
mpc_not_rohit=len(not_rohit_df)/sum(not_rohit_df["100's"])
mpc_not_viru=len(not_viru_df)/sum(not_viru_df["100's"])
mpc_not_gabbar=len(not_gabbar_df)/sum(not_gabbar_df["100's"])

# %%
mpc_not_rohit,mpc_not_viru,mpc_not_gabbar
# Out:
# (25.88157894736842, 37.89402985074627, 25.505555555555556)

# %%
mpc_f_rohit=mpc_rohit/mpc_not_rohit
mpc_f_viru=mpc_viru/mpc_not_viru
mpc_f_gabbar=mpc_gabbar/mpc_not_gabbar

# %%
mpc_f_rohit,mpc_f_viru,mpc_f_gabbar
# Out:
# (0.1993695983731571, 0.40526549743139606, 0.2882878265660435)

# %%
mpf_rohit=len(rdf)/sum(rdf["50's"])
mpf_viru=len(vdf)/sum(vdf["50's"])
mpf_gabbar=len(gdf)/sum(gdf["50's"])

mpf_rohit,mpf_viru,mpf_gabbar
# Out:
# (4.3, 6.323529411764706, 4.8076923076923075)

# %%
mpf_n_rohit=len(not_rohit_df)/sum(not_rohit_df["50's"])
mpf_n_viru=len(not_viru_df)/sum(not_viru_df["50's"])
mpf_n_gabbar=len(not_gabbar_df)/sum(not_gabbar_df["50's"])
mpf_n_rohit,mpf_n_viru,mpf_n_gabbar
# Out:
# (7.6282548476454295, 7.887232059645853, 7.6135986733001655)

# %%
mpf_f_rohit=mpf_rohit/mpf_n_rohit
mpf_f_viru=mpf_viru/mpf_n_viru
mpf_f_gabbar=mpf_gabbar/mpf_n_gabbar

# %%
mpf_f_rohit,mpf_f_viru,mpf_f_gabbar
# Out:
# (0.5636938049241048, 0.8017425332415844, 0.6314612201129299)

# %%
#100*sum(sdf['Innings Runs Scored Num'])/(sum(non_sachin_df[non_sachin_df.Country == 'India']['Innings Runs Scored Num'])+
#sum(sdf['Innings Runs Scored Num']))

# %%
100*sum(rdf['Innings Runs Scored Num'])/sum(not_rohit_df[not_rohit_df['Country']=='India']['Innings Runs Scored Num']+
sum(rdf['Innings Runs Scored Num']))
# Out:
# 0.08742621047710068

# %%
100*sum(vdf['Innings Runs Scored Num'])/sum(not_viru_df[not_viru_df['Country']=='India']['Innings Runs Scored Num']+
sum(vdf['Innings Runs Scored Num']))
# Out:
# 0.03603036763310223

# %%
100*sum(gdf['Innings Runs Scored Num'])/sum(not_gabbar_df[not_gabbar_df['Country']=='India']['Innings Runs Scored Num']+
sum(gdf['Innings Runs Scored Num']))
# Out:
# 0.08701676997865171
